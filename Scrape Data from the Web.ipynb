# %% [markdown]
# ## Scrape Data
#
# In this phase, we'll gather review data from the web, focusing on the airline.
# Utilize the Skytrax website for this purpose and aim to collect extensive data to enhance our analysis.

# %%
#imports

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests 
import re

# %%
# Initialize a list to store review data
reviews_data = []

for i in range(1, 39):
    # Make a request to the airline reviews page
    page = requests.get(f"https://www.airlinequality.com/airline-reviews/british-airways/page/{i}/?sortby=post_date%3ADesc&pagesize=100")
 
    # Parse HTML using Beautiful Soup
    soup = BeautifulSoup(page.content, 'html.parser')

    # Loop through each review element
    for review_elem in soup.find_all('article', class_='comp_media-review-rated'):
        review_data = {}

        # Extract rating information
        rating_elem = review_elem.find('span', itemprop='ratingValue')
        if rating_elem:
            review_data['Rating'] = int(rating_elem.get_text())

        # Extract title information
        title_elem = review_elem.find('h2', class_='text_header')
        if title_elem:
            review_data['Title'] = title_elem.get_text().strip()

        # Extract author and date information
        author_elem = review_elem.find('span', itemprop='author')
        date_elem = review_elem.find('time', itemprop='datePublished')
        country_elem = review_elem.find('h3', class_='text_sub_header')

        if author_elem and date_elem and country_elem:
            review_data['Author'] = author_elem.get_text().strip()
            review_data['Date'] = date_elem.get('datetime')
            country_text = country_elem.get_text()
            review_data['Country'] = country_text.split('(')[-1].split(')')[0]

        # Extract review information
        body_elem = review_elem.find('div', class_='text_content')
        if body_elem:
            review_data['Review'] = body_elem.get_text().strip()

        # Extract rating details
        rating_elems = review_elem.find_all('tr')
        for rating in rating_elems:
            header = rating.find('td', class_='review-rating-header')
            value = rating.find('td', class_='review-value')
            if header and value:
                review_data[header.get_text().strip()] = value.get_text().strip()

         # Extract star information for each rating category
        star_elems = review_elem.find_all('td', class_='review-rating-stars stars')
        for star_elem in star_elems:
            header = star_elem.find_previous_sibling('td', class_='review-rating-header')
            if header:
                stars = len(star_elem.find_all('span', class_='star fill'))
                review_data[header.get_text().strip()] = stars

        # Append review data to the list reviews_data
        reviews_data.append(review_data)
    
# Create a DataFrame from the list reviews_data
df = pd.DataFrame(reviews_data)
df
# Out:
#       Rating                                  Title  \
# 0        8.0  "stick to their cabin bag size limit"
# 1        8.0        "crew were attentive, friendly"
# 2        3.0                   "Utterly outrageous"
# 3        3.0           "They have a long way to go"
# 4        7.0                   "FA's were friendly"
# ...      ...                                    ...
# 3766     1.0        British Airways customer review
# 3767     9.0        British Airways customer review
# 3768     5.0        British Airways customer review
# 3769     4.0        British Airways customer review
# 3770     4.0        British Airways customer review
#
#                                Author        Date         Country  \
# 0     4 reviews\n\n\n\nMichael Powell  2024-03-21  United Kingdom
# 1                            N Wardan  2024-03-21          Canada
# 2                  Solomon Pachtinger  2024-03-19  United Kingdom
# 3                        Paul Roberts  2024-03-19       Singapore
# 4         42 reviews\n\n\n\nE Carmere  2024-03-14         Belgium
# ...                               ...         ...             ...
# 3766                      J Robertson  2012-08-29  United Kingdom
# 3767                       Nick Berry  2012-08-28  United Kingdom
# 3768                    Avril Barclay  2011-10-12  United Kingdom
# 3769                           C Volz  2011-10-11   United States
# 3770                        Russ King  2011-10-09  United Kingdom
#
#                                                  Review  \
# 0     Not Verified |  The flight was comfortable eno...
# 1     ✅ Trip Verified |  We had a really good flying...
# 2     ✅ Trip Verified |  Waited an hour to check-in ...
# 3     Not Verified |   Not a great experience at all...
# 4     ✅ Trip Verified |  Boarding was difficult caus...
# ...                                                 ...
# 3766  This was a bmi Regional operated flight on a R...
# 3767  LHR to HAM. Purser addresses all club passenge...
# 3768  My son who had worked for British Airways urge...
# 3769  London City-New York JFK via Shannon on A318 b...
# 3770  SIN-LHR BA12 B747-436 First Class. Old aircraf...
#
#                               Aircraft Type Of Traveller        Seat Type  \
# 0                                 A320      Solo Leisure    Economy Class
# 1     Boeing 787-8 /777-200 / A320-200    Family Leisure    Economy Class
# 2                                 A321          Business   Business Class
# 3                       Boeing 777-300          Business   Business Class
# 4                                 A320      Solo Leisure   Business Class
# ...                                ...               ...              ...
# 3766                               NaN               NaN    Economy Class
# 3767                               NaN               NaN   Business Class
# 3768                               NaN               NaN    Economy Class
# 3769                               NaN               NaN  Premium Economy
# 3770                               NaN               NaN      First Class
#
#                                        Route  Date Flown Recommended  \
# 0                London Heathrow to Toulouse  March 2024         yes
# 1     Montreal to Venice via London Heathrow  March 2024         yes
# 2                           Paphos to London  March 2024          no
# 3                          London to Houston  March 2024          no
# 4                London Heathrow to Brussels  March 2024         yes
# ...                                      ...         ...         ...
# 3766                                     NaN         NaN          no
# 3767                                     NaN         NaN         yes
# 3768                                     NaN         NaN         yes
# 3769                                     NaN         NaN          no
# 3770                                     NaN         NaN          no
#
#       Seat Comfort  Cabin Staff Service  Ground Service  Value For Money  \
# 0              4.0                  4.0             3.0                3
# 1              4.0                  5.0             3.0                4
# 2              2.0                  1.0             1.0                1
# 3              1.0                  3.0             1.0                1
# 4              2.0                  4.0             3.0                3
# ...            ...                  ...             ...              ...
# 3766           3.0                  1.0             NaN                3
# 3767           4.0                  5.0             NaN                3
# 3768           NaN                  NaN             NaN                4
# 3769           1.0                  3.0             NaN                1
# 3770           4.0                  5.0             NaN                2
#
#       Food & Beverages  Inflight Entertainment  Wifi & Connectivity
# 0                  NaN                     NaN                  NaN
# 1                  5.0                     4.0                  NaN
# 2                  2.0                     1.0                  2.0
# 3                  3.0                     2.0                  2.0
# 4                  3.0                     NaN                  NaN
# ...                ...                     ...                  ...
# 3766               2.0                     0.0                  NaN
# 3767               4.0                     0.0                  NaN
# 3768               NaN                     NaN                  NaN
# 3769               5.0                     0.0                  NaN
# 3770               5.0                     2.0                  NaN
#
# [3771 rows x 19 columns]

# %%
# Save the dataframe to an Excel file
df.to_excel('C:/Data Science - British Airways/Data/data_airline-reviews(British Airways).xlsx', index=False)
